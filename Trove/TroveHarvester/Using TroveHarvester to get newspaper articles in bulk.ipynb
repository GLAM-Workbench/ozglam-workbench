# %% [markdown]
# # Using TroveHarvester to get newspaper articles in bulk

# %% [markdown]
# The Trove Newspaper Harvester is a command line tool that helps you download large quantities of digitised newspaper articles from [Trove](http://trove.nla.gov.au/).
#
# Instead of working your way through page after page of search results using Trove’s web interface, the newspaper harvester will save the results of your search to a CSV (spreadsheet) file which you can then filter, sort, or analyse.
#
# Even better, the harvester can save the full OCRd (and possibly corrected) text of each article to an individual file. You could, for example, collect the text of thousands of articles on a particular topic and then feed them to a text analysis engine like [Voyant](http://voyant-tools.org/) to look for patterns in the language.
#
# If you'd like to install and run the TroveHarvester on your local system see [the installation instructions](http://timsherratt.org/digital-heritage-handbook/docs/trove-newspaper-harvester/).
#
# If you'd like to try before you buy, you can run a fully-functional version of the TroveHarvester from this very notebook!

# %% [markdown]
# ## Getting started

# %% [markdown]
# If you were running TroveHarvester on your local system, you could access the basic help information by entering this on the command line:
#
# ``` bash
# troveharvester -h
# ```
#
# In this notebook you need to use the magic `%run` command to call the TroveHarvester script. Try this:

# %%
# %run -m troveharvester -h
# Out:
# usage: troveharvester [-h] {start,restart,report} ...
#
# positional arguments:
#   {start,restart,report}
#     start               Start a new harvest
#     restart             Restart an unfinished harvest
#     report              Report on a harvest
#
# optional arguments:
#   -h, --help            show this help message and exit

# %% [markdown]
# Before we go any further you should make sure you have a Trove API key. For non-commercial projects, you just  fill out a simple form and your API key is generated instantly. Follow the instructions in the Trove Help to [obtain your own Trove API Key](http://help.nla.gov.au/trove/building-with-trove/api).
#
# Once you've created a key, you can access it at any time on the 'For developers' tab of your Trove user profile.
#
# Copy your API key now, and paste it in the cell below, between the quotes.

# %%
api_key = '6pi5hht0d2umqcro'
print('Your API key is: {}'.format(api_key))
# Out:
# Your API key is: 6pi5hht0d2umqcro

# %% [markdown]
# ## What do you want to harvest?

# %% [markdown]
# The TroveHarvester translates queries from the Trove web interface into something that the API can understand. So all you need to do is construct your query using the web interface. Once you're happy with the results you're getting just copy the url.
#
# It's important to note that there are currently a few differences between the indexes used by the web interface and the API, so some queries won't translate directly. For example, the `state` facet doesn't exist in the API index. If you use the `state` facet the TroveHarvester will try to replace it with a list of newspapers from that state, but there are now so many newspaper titles that this could fail. Similarly, the API index won't recognise `has:corrections`. However, most queries should translate without any problems.
#
# Once you've constructed your query and copied the url, paste it between the quotes in the cell below.

# %%
query = 'https://trove.nla.gov.au/newspaper/result?q=wragge+cyclone'

# %%
# %run -m troveharvester start $query $api_key --text
# Out:
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=0
# Harvested: 20
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=20
# Harvested: 40
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=40
# Harvested: 60
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=60
# Harvested: 80
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=80
# Harvested: 100
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=100
# Harvested: 120
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=120
# Harvested: 140
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=140
# Harvested: 160
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=160
# Harvested: 180
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=180
# Harvested: 200
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=200
# Harvested: 220
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=220
# Harvested: 240
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=240
# Harvested: 260
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=260
# Harvested: 280
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=280
# Harvested: 300
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=300
# Harvested: 320
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=320
# Harvested: 340
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=340
# Harvested: 360
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=360
# Harvested: 380
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=380
# Harvested: 400
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=400
# Harvested: 420
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=420
# Harvested: 440
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=440
# Harvested: 460
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=460
# Harvested: 480
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=480
# Harvested: 500
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=500
# Harvested: 520
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=520
# Harvested: 540
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=540
# Harvested: 560
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=560
# Harvested: 580
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=580
# Harvested: 600
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=600
# Harvested: 620
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=620
# Harvested: 640
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=640
# Harvested: 660
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=660
# Harvested: 680
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=680
# Harvested: 700
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=700
# Harvested: 720
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=720
# Harvested: 740
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=740
# Harvested: 760
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=760
# Harvested: 780
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=780
# Harvested: 800
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=800
# Harvested: 820
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=820
# Harvested: 840
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=840
# Harvested: 860
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=860
# Harvested: 880
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=880
# Harvested: 900
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=900
# Harvested: 920
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=920
# Harvested: 940
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s=940
# Harvested: 960
# http://api.trove.nla.gov.au/result?q=wragge+cyclone&encoding=json&zone=newspaper&reclevel=full&include=articleText&n=20&key=6pi5hht0d2umqcro&s